# %%
import seaborn as sns
tip1=sns.load_dataset('tips')
tip1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip2=tip1.drop('tip',axis=1)
tip3=tip1['tip']

# %%
tip3.shape
# Out:
# (244,)

# %% [markdown]
# titanic data set

# %%
import seaborn as sns
tda=sns.load_dataset('titanic')

# %%
tda
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tda_feature=tda.drop('survived',axis=1)
tda_target=tda['survived']
tda_feature
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
tda_target.shape
# Out:
# (891,)

# %%
sizes=tip1['size']
import numpy as np
sizes.loc[:15]=np.nan
# Out:
# C:\Users\saipr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sizes
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 239    3.0
# 240    2.0
# 241    2.0
# 242    2.0
# 243    2.0
# Name: size, Length: 244, dtype: float64

# %%
tip1['size'].isnull().sum()
# Out:
# 16

# %%
mean=sizes.mean()
mean=round(mean)
mean
# Out:
# 3

# %%
sizes.fillna(mean,inplace=True)
sizes
# Out:
# 0      3.0
# 1      3.0
# 2      3.0
# 3      3.0
# 4      3.0
#       ...
# 239    3.0
# 240    2.0
# 241    2.0
# 242    2.0
# 243    2.0
# Name: size, Length: 244, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(sizes)
plt.show()

# %%
min_value=sizes.mean()-(3*sizes.std())
min_value
# Out:
# -0.1974349065787404

# %%
max_value=sizes.mean()+(3*sizes.std())
max_value
# Out:
# 5.369566054119724

# %%
sizes=sizes[sizes<=max_value]

# %%
sizes
# Out:
# 0      3.0
# 1      3.0
# 2      3.0
# 3      3.0
# 4      3.0
#       ...
# 239    3.0
# 240    2.0
# 241    2.0
# 242    2.0
# 243    2.0
# Name: size, Length: 240, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
enc=LabelEncoder()

# %%
tda_feature['sex']=enc.fit_transform(tda_feature['sex'].astype('str'))
tda_feature['embarked']=enc.fit_transform(tda_feature['embarked'].astype('str'))
tda_feature['class']=enc.fit_transform(tda_feature['class'].astype('str'))
tda_feature['embarked']=enc.fit_transform(tda_feature['embarked'].astype('str'))
tda_feature['who']=enc.fit_transform(tda_feature['who'].astype('str'))

# %%
tda_feature=tda_feature.drop('adult_male',axis=1)

# %%
tda_feature
# Out:
#      pclass  sex   age  sibsp  parch     fare  embarked  class  who deck  \
# 0         3    1  22.0      1      0   7.2500         2      2    1  NaN
# 1         1    0  38.0      1      0  71.2833         0      0    2    C
# 2         3    0  26.0      0      0   7.9250         2      2    2  NaN
# 3         1    0  35.0      1      0  53.1000         2      0    2    C
# 4         3    1  35.0      0      0   8.0500         2      2    1  NaN
# ..      ...  ...   ...    ...    ...      ...       ...    ...  ...  ...
# 886       2    1  27.0      0      0  13.0000         2      1    1  NaN
# 887       1    0  19.0      0      0  30.0000         2      0    2    B
# 888       3    0   NaN      1      2  23.4500         2      2    2  NaN
# 889       1    1  26.0      0      0  30.0000         0      0    1    C
# 890       3    1  32.0      0      0   7.7500         1      2    1  NaN
#
#      embark_town alive  alone
# 0    Southampton    no  False
# ...

# %%
tda_feature.isnull().sum()
# Out:
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
tda_feature['deck']=tda_feature['deck'].replace("NaN",'0')

# %%
tda_feature['alive']=enc.fit_transform(tda_feature['alive'].astype('str'))

# %%
tda_feature['alone']=enc.fit_transform(tda_feature['alone'].astype('str'))
tda_feature['embark_town']=enc.fit_transform(tda_feature['embark_town'].astype('str'))
tda_feature['deck']=enc.fit_transform(tda_feature['deck'].astype('str'))

# %%
tda_feature
# Out:
#      pclass  sex   age  sibsp  parch     fare  embarked  class  who  deck  \
# 0         3    1  22.0      1      0   7.2500         2      2    1     7
# 1         1    0  38.0      1      0  71.2833         0      0    2     2
# 2         3    0  26.0      0      0   7.9250         2      2    2     7
# 3         1    0  35.0      1      0  53.1000         2      0    2     2
# 4         3    1  35.0      0      0   8.0500         2      2    1     7
# ..      ...  ...   ...    ...    ...      ...       ...    ...  ...   ...
# 886       2    1  27.0      0      0  13.0000         2      1    1     7
# 887       1    0  19.0      0      0  30.0000         2      0    2     1
# 888       3    0   NaN      1      2  23.4500         2      2    2     7
# 889       1    1  26.0      0      0  30.0000         0      0    1     2
# 890       3    1  32.0      0      0   7.7500         1      2    1     7
#
#      embark_town  alive  alone
# 0              2      0      0
# ...

# %%
tda_normalized=(tda_feature-tda_feature.mean())/tda_feature.std()

# %%
tda_normalized
# Out:
#        pclass       sex       age     sibsp     parch      fare  embarked  \
# 0    0.826913  0.737281 -0.530005  0.432550 -0.473408 -0.502163  0.580788
# 1   -1.565228 -1.354813  0.571430  0.432550 -0.473408  0.786404 -1.937372
# 2    0.826913 -1.354813 -0.254646 -0.474279 -0.473408 -0.488580  0.580788
# 3   -1.565228 -1.354813  0.364911  0.432550 -0.473408  0.420494  0.580788
# 4    0.826913  0.737281  0.364911 -0.474279 -0.473408 -0.486064  0.580788
# ..        ...       ...       ...       ...       ...       ...       ...
# 886 -0.369158  0.737281 -0.185807 -0.474279 -0.473408 -0.386454  0.580788
# 887 -1.565228 -1.354813 -0.736524 -0.474279 -0.473408 -0.044356  0.580788
# 888  0.826913 -1.354813       NaN  0.432550  2.007806 -0.176164  0.580788
# 889 -1.565228  0.737281 -0.254646 -0.474279 -0.473408 -0.044356 -1.937372
# 890  0.826913  0.737281  0.158392 -0.474279 -0.473408 -0.492101 -0.678292
#
#         class       who      deck  embark_town     alive     alone
# ...

# %%
tda_standard=(tda_feature-tda_feature.min())/(tda_feature.max()-tda_feature.min())

# %%
tda_standard
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  class  who  \
# 0       1.0  1.0  0.271174  0.125  0.000000  0.014151  0.666667    1.0  0.5
# 1       0.0  0.0  0.472229  0.125  0.000000  0.139136  0.000000    0.0  1.0
# 2       1.0  0.0  0.321438  0.000  0.000000  0.015469  0.666667    1.0  1.0
# 3       0.0  0.0  0.434531  0.125  0.000000  0.103644  0.666667    0.0  1.0
# 4       1.0  1.0  0.434531  0.000  0.000000  0.015713  0.666667    1.0  0.5
# ..      ...  ...       ...    ...       ...       ...       ...    ...  ...
# 886     0.5  1.0  0.334004  0.000  0.000000  0.025374  0.666667    0.5  0.5
# 887     0.0  0.0  0.233476  0.000  0.000000  0.058556  0.666667    0.0  1.0
# 888     1.0  0.0       NaN  0.125  0.333333  0.045771  0.666667    1.0  1.0
# 889     0.0  1.0  0.321438  0.000  0.000000  0.058556  0.000000    0.0  0.5
# 890     1.0  1.0  0.396833  0.000  0.000000  0.015127  0.333333    1.0  0.5
#
#          deck  embark_town  alive  alone
# ...
